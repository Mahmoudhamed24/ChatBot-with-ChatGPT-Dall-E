# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahmoudhamed24/ChatBot-with-ChatGPT-Dall-E/blob/master/Spotify.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In the Spotify dataset, there are different column values as well as artist name, rank, and popularity that we used in our task. Create private playlists using different column values.
#
# Playlist of upbeat music only: Use the Tempo column to select the appropriate tempo.
#
# If you create a playlist, save it as an Excel file and share it with your fellow learners.
# Saving a DataFrame as an Excel file is very simple.
#
# في مجموعة بيانات Spotify، توجد قيم أعمدة مختلفة بالإضافة إلى اسم الفنان ورتبته وشعبيته التي استخدمناها في مهمتنا. قم بإنشاء قوائم تشغيل خاصة باستخدام قيم أعمدة مختلفة.
#
# قائمة تشغيل الموسيقى المبهجة فقط: استخدم عمود Tempo لتحديد الإيقاع المناسب.
#
# إذا قمت بإنشاء قائمة تشغيل، فاحفظها كملف Excel وشاركها مع زملائك المتعلمين.
# يعد حفظ DataFrame كملف Excel أمرًا بسيطًا للغاية.
#
# Date:
#
# https://www.kaggle.com/datasets/prasertk/spotify-global-2019-moststreamed-tracks

# %%
import pandas as pd

# %%
spotify_df =pd.read_csv('/content/spotify.csv')

# %%
upbeat_music = spotify_df[spotify_df['tempo'] > 120]

# %%
upbeat_songs_playlist = upbeat_music[['Artist', 'Track Name']]

# %%
upbeat_music
# Out:
#      Country    Rank                Track_id     Streams  \
# 0     global     1.0  25sgk305KZfyuqVBQIahim  1166185736
# 1     global     2.0  2Fxmhks0bxGSBdJ92vM42m  1052358787
# 2     global     3.0  6ocbgoVGwYJhOv1GgI9NsF   789094044
# 10    global    11.0  5p7ujcrUXASCNwRaWNHR1C   605653817
# 11    global    12.0  5iwz1NiezX7WWjnCgY5TH4   591435651
# ...      ...     ...                     ...         ...
# 1704  global  1705.0  3567eNX2L3RkkMkwspncMH      601762
# 1705  global  1706.0  6rPO02ozF3bM7NnOV4h6s2      592324
# 1707  global  1708.0  3gicyfiEVMGONgzygpWjNT      585922
# 1711  global  1712.0  0PaAB17axL9hn88mHiw8g0      560658
# 1715  global  1716.0  7rLegaz7zKB6EtDNzcslKE      536447
#
#                               Track Name               Artist  \
# 0                       Sweet but Psycho              Ava Max
# 1                                bad guy        Billie Eilish
# 2                                7 rings        Ariana Grande
# ...

# %%
upbeat_songs_playlist
# Out:
#                    Artist                          Track Name
# 0                 Ava Max                    Sweet but Psycho
# 1           Billie Eilish                             bad guy
# 2           Ariana Grande                             7 rings
# 10                 Halsey                          Without Me
# 11             Pedro Capó                       Calma - Remix
# ...                   ...                                 ...
# 1704  5 Seconds of Summer                           Lie To Me
# 1705           Luis Fonsi                   Despacito - Remix
# 1707                 Seeb                                Grip
# 1711   Humberto & Ronaldo                Não Fala Não pra Mim
# 1715     MC Kevin o Chris  Medley da Gaiola - Dennis DJ Remix
#
# [864 rows x 2 columns]

# %%
upbeat_music.to_excel('upbeat_music_playlist.xlsx', index=False)

# %%
upbeat_songs_playlist.to_excel('upbeat_songs_playlist.xlsx', index=False)
